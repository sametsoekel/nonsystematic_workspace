# %%
library(tidyverse)

# %% [markdown]
# ### Re-creating the plots which mentioned at page 21 (6th Question)

# %%
mpg %>% ggplot(aes(displ,hwy))+geom_point()+geom_smooth(se=F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
mpg %>% ggplot(aes(displ,hwy))+geom_point()+geom_smooth(aes(group=drv),se=F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
mpg %>% ggplot(aes(displ,hwy))+geom_point(aes(color=drv))+geom_smooth(aes(color=drv),se=F)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# #### geom_bar() already represents "count" by default, I can specify that by passing y arguement as ..prop.. (proportion)

# %%
mpg %>% ggplot + geom_bar(aes(x=drv,y=..prop..,group=1)) +
facet_wrap(~fl)
# Out:
# plot without title

# %%
mpg %>% ggplot + geom_col(aes(x=drv,y=hwy))
# Out:
# plot without title

# %% [markdown]
# ### How to use jitter (adding very little random noise to points to avoid overplotting)

# %%
mpg %>% ggplot() + 
geom_jitter(aes(displ,hwy))
# Out:
# plot without title

# %% [markdown]
# ### Let me check the difference between them

# %%
mpg  %>% ggplot +
geom_point(aes(displ,hwy))
# Out:
# plot without title

# %% [markdown]
# ### Some boxplot

# %%
mpg %>% ggplot(aes(hwy,fl)) + geom_boxplot() +coord_flip()
# Out:
# plot without title
